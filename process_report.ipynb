# %%
import pandas  as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_table('report.tsv',header=None)

# %%
df.columns=['Reference genes','Reference sequence lenght','Mapped read count','Unmaped read count']
#df=df[['Reference genes','Mapped read count']]

# %%
df.apply(pd.to_numeric, errors='ignore')
# Out:
#                                       Reference genes  \
# 0   Amino_Acid_ABC_transporter_permease_ABCtranspo...
# 1                           Aminoacyltransferase_FemA
# 2                               Beta-lactamase_SHV-11
# 3   Capsular_polysaccharide_biosynthesis_protein_A...
# 4                    Capsular_transport_protein__ctrA
# ..                                                ...
# 83                                      GS_StapA_entB
# 84                                       GS_StaW_sodA
# 85                                       GS_StreP_ply
# 86                                     GS_StrepA_glnQ
# 87                                                  *
#
#     Reference sequence lenght  Mapped read count  Unmaped read count
# 0                         834                  0                   0
# 1                        1263                525                   0
# 2                         861                 51                   0
# ...

# %%
df['Percentage of Mapped reads']=(df['Mapped read count']*100)/df['Mapped read count'].sum()

# %%
df[df['Percentage of Mapped reads'] > 0].plot(kind='barh',x='Reference genes',y='Percentage of Mapped reads',figsize=(5,10))
plt.xlabel('Percentage of Mapped reads')
# Out:
# Text(0.5, 0, 'Percentage of Mapped reads')
